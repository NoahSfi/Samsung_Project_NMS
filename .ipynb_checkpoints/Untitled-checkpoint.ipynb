# %%
import json
from matplotlib import pyplot as plt
import numpy as np
with open('class_train_AP/car.json') as json_file:
    data = json.load(json_file)
    dicTrain = data[0]
with open('class_value_AP/car.json') as json_file:
    data = json.load(json_file)
    dicValue = data[0]

iousValue = dicValue['iou_threshold']
threshold = dicValue['AP[IoU:0.5]']

# %%
print(dicValue)
# Out:
# {'iou_threshold': [0.1, 0.11816326530612245, 0.1363265306122449, 0.15448979591836737, 0.1726530612244898, 0.19081632653061226, 0.2089795918367347, 0.22714285714285715, 0.2453061224489796, 0.26346938775510204, 0.2816326530612245, 0.2997959183673469, 0.3179591836734694, 0.33612244897959187, 0.3542857142857143, 0.37244897959183676, 0.3906122448979592, 0.40877551020408165, 0.4269387755102041, 0.44510204081632654, 0.463265306122449, 0.48142857142857143, 0.4995918367346939, 0.5177551020408163, 0.5359183673469388, 0.5540816326530612, 0.5722448979591837, 0.5904081632653061, 0.6085714285714285, 0.626734693877551, 0.6448979591836734, 0.6630612244897959, 0.6812244897959183, 0.6993877551020408, 0.7175510204081632, 0.7357142857142857, 0.7538775510204081, 0.7720408163265305, 0.790204081632653, 0.8083673469387754, 0.8265306122448979, 0.8446938775510203, 0.8628571428571428, 0.8810204081632652, 0.8991836734693877, 0.9173469387755101, 0.9355102040816325, 0.953673469387755, 0.9718367346938775, 0.99], '
# ...
